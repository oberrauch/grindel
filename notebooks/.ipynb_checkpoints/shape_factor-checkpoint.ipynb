# %% [markdown]
# # Shape factors
# Some more tuning tests...

# %%
# %%javascript
# // Run model without shape factor and store results
# var i;
# for(i=2; i<30; i++) {
#     Jupyter.notebook.execute_cells([i]);
# }
#
# // Run model again, but with Nye's shape factor
# for(i=6; i<28; i++) {
#     Jupyter.notebook.execute_cells([i]);
# }
#
# // store results
# for(i=30; i<=31; i++) {
#     Jupyter.notebook.execute_cells([i]);
# }
#
# // Run model again, but with Huss' shape factor
# for(i=6; i<28; i++) {
#     Jupyter.notebook.execute_cells([i]);
# }
#
# // run through rest of cells, combining lenght records and
# // plotting results
# for(i=32; i<36; i++) {
#     Jupyter.notebook.execute_cells([i]);
# }

# %% [markdown]
# ## Import

# %%
# import externals libs
import os
import shutil
import numpy as np
import pandas as pd
import xarray as xr
import geopandas as gpd
import matplotlib.pyplot as plt

# import OGGM modules
import oggm
from oggm import cfg, graphics, utils
from oggm.utils import get_demo_file, get_rgi_glacier_entities
from oggm.tests.funcs import get_test_dir
from oggm.core import gis, climate, centerlines, massbalance, flowline, inversion

# %% [markdown]
# ## Initialize

# %%
# load default parameter file
cfg.initialize()
# specify working directory
wdir = '/Users/oberrauch/work/grindelwald/working_directories/working_example/'
cfg.PATHS['working_dir'] = wdir

# using intersects
cfg.PARAMS['use_intersects'] = True

# define big border
cfg.PARAMS['border'] = 50

# set climate/massbalance hyper parameters for HistAlp dataset
cfg.PARAMS['baseline_climate'] = 'HISTALP'
cfg.PARAMS['prcp_scaling_factor'] = 1.75
cfg.PARAMS['temp_melt'] = -1.75
# Out:
# 2019-04-12 13:20:53: oggm.cfg: Using configuration file: /Users/oberrauch/oggm-fork/oggm/params.cfg

# %% [markdown]
# ## Preprocessing

# %%
# get RGI entity
rgi_id = 'RGI60-11.01270'
rgi_df = get_rgi_glacier_entities([rgi_id], version='6')
rgi_entity = rgi_df.iloc[0]
rgi_df.plot()

# %%
# specify intersects
cfg.set_intersects_db(utils.get_rgi_intersects_region_file('11'))

# %%
# prepare glacier directory
gdir = oggm.GlacierDirectory(rgi_entity, reset=True)

# %% [markdown]
# ### GIS

# %%
# GIS tasks
gis.define_glacier_region(gdir, entity=rgi_entity)
gis.glacier_masks(gdir)
gdir
# Out:
# 2019-04-12 13:21:50: oggm.core.gis: (RGI60-11.01270) define_glacier_region
# 2019-04-12 13:21:50: oggm.core.gis: (RGI60-11.01270) glacier_masks
# <oggm.GlacierDirectory>
#   RGI id: RGI60-11.01270
#   Region: 11: Central Europe
#   Subregion: 11-01: Alps
#   Glacier type: Glacier
#   Terminus type: Land-terminating
#   Area: 9.023 km2
#   Lon, Lat: (8.11933, 46.6143)
#   Grid (nx, ny): (192, 183)
#   Grid (dx, dy): (52.0, -52.0)

# %% [markdown]
# ### Centerlines

# %%
# run center line preprocessing tasks
centerlines.compute_centerlines(gdir)
centerlines.initialize_flowlines(gdir)
centerlines.compute_downstream_line(gdir)
centerlines.compute_downstream_bedshape(gdir)
centerlines.catchment_area(gdir)
centerlines.catchment_intersections(gdir)
centerlines.catchment_width_geom(gdir)
centerlines.catchment_width_correction(gdir)
# Out:
# 2019-04-12 13:21:51: oggm.core.centerlines: (RGI60-11.01270) compute_centerlines
# 2019-04-12 13:21:51: oggm.core.centerlines: (RGI60-11.01270) initialize_flowlines
# 2019-04-12 13:21:51: oggm.core.centerlines: (RGI60-11.01270) compute_downstream_line
# 2019-04-12 13:21:51: oggm.core.centerlines: (RGI60-11.01270) compute_downstream_bedshape
# 2019-04-12 13:21:52: oggm.core.centerlines: (RGI60-11.01270) catchment_area
# 2019-04-12 13:21:54: oggm.core.centerlines: (RGI60-11.01270) catchment_intersections
# 2019-04-12 13:21:54: oggm.core.centerlines: (RGI60-11.01270) catchment_width_geom
# 2019-04-12 13:21:55: oggm.core.centerlines: (RGI60-11.01270) catchment_width_correction

# %% [markdown]
# ### Climate and mass balance parameters

# %%
# process the HistAlp climate file
climate.process_histalp_data(gdir)
climate.local_t_star(gdir)
climate.mu_star_calibration(gdir)
# Out:
# 2019-04-12 13:21:55: oggm.core.climate: (RGI60-11.01270) process_histalp_data
# 2019-04-12 13:21:58: oggm.core.climate: (RGI60-11.01270) local_t_star
# 2019-04-12 13:21:58: oggm.core.climate: (RGI60-11.01270) local mu* computation for t*=1909
# 2019-04-12 13:21:58: oggm.core.climate: (RGI60-11.01270) mu_star_calibration

# %% [markdown]
# ### Mass balance

# %%
# istance mass balance model using the historic climate file
mb_model = massbalance.PastMassBalance(gdir)

# %% [markdown]
# ### Inversion

# %%
# run ice thicknes inversion
inversion.prepare_for_inversion(gdir)
inversion.mass_conservation_inversion(gdir)
inversion.filter_inversion_output(gdir)
# Out:
# 2019-04-12 13:21:59: oggm.core.inversion: (RGI60-11.01270) prepare_for_inversion
# 2019-04-12 13:21:59: oggm.core.inversion: (RGI60-11.01270) mass_conservation_inversion
# 2019-04-12 13:21:59: oggm.core.inversion: Shape factor Huss used, took 1 iterations for convergence.
# 2019-04-12 13:21:59: oggm.core.inversion: Shape factor Huss used, took 3 iterations for convergence.
# 2019-04-12 13:21:59: oggm.core.inversion: Shape factor Huss used, took 1 iterations for convergence.
# 2019-04-12 13:21:59: oggm.core.inversion: Shape factor Huss used, took 5 iterations for convergence.
# 2019-04-12 13:21:59: oggm.core.inversion: (RGI60-11.01270) filter_inversion_output

# %%
# visualize ice thickness
inversion.distribute_thickness_interp(gdir)
graphics.plot_distributed_thickness([gdir])
# Out:
# 2019-04-12 13:21:59: oggm.core.inversion: (RGI60-11.01270) distribute_thickness_interp
# 2019-04-12 13:21:59: oggm.core.gis: (RGI60-11.01270) interpolation_masks

# %% [markdown]
# ### Dynamic model

# %%
# finalize the preporcessing
flowline.init_present_time_glacier(gdir)
# Out:
# 2019-04-12 13:22:00: oggm.core.flowline: (RGI60-11.01270) init_present_time_glacier

# %% [markdown]
# ## Model

# %%
# read needed file
ci =  gdir.read_pickle('climate_info')
fls = gdir.read_pickle('model_flowlines')

# %%
# now we can use the flowline model
model = flowline.FluxBasedModel(fls, mb_model=mb_model, y0=ci['baseline_hydro_yr_0'])

# %%
# run model over entire HistAlp period
run_ds, diag_ds = model.run_until_and_store(2014)

# %% [markdown]
# ## Results

# %%
# get modeled length changes as DataFrame (for multiple flowline)
length_no_shape = diag_ds.length_m.to_dataframe()[['hydro_year','length_m']]
length_no_shape = length_no_shape.reindex(index=length_no_shape.hydro_year)
length_no_shape.drop('hydro_year', axis=1, inplace=True)
length_no_shape.columns = ['no_shape']

# %%
# cell N° 29 (starting with 0)
# use 'Nye' shape factor
cfg.PARAMS['use_shape_factor_for_inversion'] = 'Nye'
cfg.PARAMS['use_shape_factor_for_fluxbasedmodel'] = 'Nye'

# %%
# get modeled length changes as DataFrame (for multiple flowline)
length_nye_shape = diag_ds.length_m.to_dataframe()[['hydro_year','length_m']]
length_nye_shape = length_nye_shape.reindex(index=length_nye_shape.hydro_year)
length_nye_shape.drop('hydro_year', axis=1, inplace=True)
length_nye_shape.columns = ['nye_shape']

# %%
# cell N° 31 (starting with 0)
# use 'Nye' shape factor
cfg.PARAMS['use_shape_factor_for_inversion'] = 'Huss'
cfg.PARAMS['use_shape_factor_for_fluxbasedmodel'] = 'Huss'

# %%
# get modeled length changes as DataFrame (for multiple flowline)
length_huss_shape = diag_ds.length_m.to_dataframe()[['hydro_year','length_m']]
length_huss_shape = length_huss_shape.reindex(index=length_huss_shape.hydro_year)
length_huss_shape.drop('hydro_year', axis=1, inplace=True)
length_huss_shape.columns = ['huss_shape']

# %%
# get reference length
from oggm.grindel.utils import get_leclercq_length
length_ref = get_leclercq_length('11.01270')

# %%
# combine both records
length_df = pd.concat([length_ref, length_no_shape, length_nye_shape, length_huss_shape], axis=1)
# reference year for length change measurements
year_ref_zero = length_ref.abs().idxmin()
# get mean modeled length at reference year
length_offset = length_df.loc[year_ref_zero, ['no_shape', 'nye_shape', 'huss_shape']].mean(axis=1).iloc[0]
length_df.ref += length_offset

# %%
# plot lenght changes
ax = length_df.plot(figsize=[10,6])
ax.get_lines()[0].set_marker('.')
